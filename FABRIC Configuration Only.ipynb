# %% [markdown]
# # P4Lang Tutorials of FABRIC
#
# This notebook walks the user through setting up a FABRIC eperiment that is suitiable for completing the P4 tutorials created by [P4Lang](https://github.com/p4lang/tutorials). The tutorials were origianlly designed to use a mininet topology. This example replaces the mininet topology with a FABRIC experiemnt topology that may span multiple sites across the FABRIC testbed.
#
# Additional resources:
# - [FABRIC Knowledge Base](https://learn.fabric-testbed.net/)
# - [FABRIC Forums](https://learn.fabric-testbed.net/forums/)
# - [P4Lang Tutorials](https://github.com/p4lang/tutorials)
# - [P4Lang YouTube Presentations](https://www.youtube.com/channel/UCOQAFkDKucJWr-KafdJsdIQ)

# %% [markdown]
# ## Basic FABRIC Slice Configuration

# %%
import json
import traceback
from fabrictestbed_extensions.fablib.fablib import fablib

# %%
try:
    print(f"{fablib.list_sites()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_f401e caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_f401e th {
#   text-align: left;
# }
# #T_f401e tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f401e tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_f401e .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f401e_row0_col0, #T_f401e_row0_col1, #T_f401e_row0_col2, #T_f401e_row0_col3, #T_f401e_row0_col4, #T_f401e_row0_col5, #T_f401e_row0_col6, #T_f401e_row0_col7, #T_f401e_row0_col8, #T_f401e_row0_col9, #T_f401e_row0_col10, #T_f401e_row0_col11, #T_f401e_row0_col12, #T_f401e_row0_col13, #T_f401e_row0_col14, #T_f401e_row0_col15, #T_f401e_row0_col16, #T_f401e_row0_col17, #T_f401e_row0_col18, #T_f401e_row0_col19, #T_f401e_row0_col20, #T_f401e_row0_col21, #T_f401e_row0_col22, #T_f401e_row0_col23, #T_f401e_row0_col24, #T_f401e_row0_col25, #T_f401e_row0_col26, #T_f401e_row0_col27, #T_f401e_row0_col28, #T_f401e_row0_col29, #T_f401e_row0_col30, #T_f401e_row0_col31, #T_f401e_row1_col0, #T_f401e_row1_col1, #T_f401e_row1_col2, #T_f401e_row1_col3, #T_f401e_row1_col4, #T_f401e_row1_col5, #T_f401e_row1_col6, #T_f401e_row1_col7, #T_f401e_row1_col8, #T_f401e_row1_col9, #T_f401e_row1_col10, #T_f401e_row1_col11, #T_f401e_row1_col12, #T_f401e_row1_col13, #T_f401e_row1_col14, #T_f401e_row1_col15, #T_f401e_row1_col16, #T_f401e_row1_col17, #T_f401e_row1_col18, #T_f401e_row1_col19, #T_f401e_row1_col20, #T_f401e_row1_col21, #T_f401e_row1_col22, #T_f401e_row1_col23, #T_f401e_row1_col24, #T_f401e_row1_col25, #T_f401e_row1_col26, #T_f401e_row1_col27, #T_f401e_row1_col28, #T_f401e_row1_col29, #T_f401e_row1_col30, #T_f401e_row1_col31, #T_f401e_row2_col0, #T_f401e_row2_col1, #T_f401e_row2_col2, #T_f401e_row2_col3, #T_f401e_row2_col4, #T_f401e_row2_col5, #T_f401e_row2_col6, #T_f401e_row2_col7, #T_f401e_row2_col8, #T_f401e_row2_col9, #T_f401e_row2_col10, #T_f401e_row2_col11, #T_f401e_row2_col12, #T_f401e_row2_col13, #T_f401e_row2_col14, #T_f401e_row2_col15, #T_f401e_row2_col16, #T_f401e_row2_col17, #T_f401e_row2_col18, #T_f401e_row2_col19, #T_f401e_row2_col20, #T_f401e_row2_col21, #T_f401e_row2_col22, #T_f401e_row2_col23, #T_f401e_row2
# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

# Slice 
slice_name = 'DDOSM-18'

[site1,site2,site3] = fablib.get_random_sites(count=3)
site1 = site2 = site3 = "TACC" # I was only able to get this working with all nodes on the same site currently
print(f"Sites: {site1},{site2},{site3}")

# Switches
s1_name = "s1"

switch_cores = 8
switch_ram = 16
switch_disk = 120

# Hosts
h1_name = "h1"
h2_name = "h2"
h3_name = "h3"
h4_name = "h4"

h1_subnet=IPv4Network('10.0.1.0/24')
h1_addr=IPv4Address('10.0.1.1')

h2_subnet=IPv4Network('10.0.2.0/24')
h2_addr=IPv4Address('10.0.2.2')

h3_subnet=IPv4Network('10.0.3.0/24')
h3_addr=IPv4Address('10.0.3.3')

h4_subnet=IPv4Network('10.0.4.0/24')
h4_addr=IPv4Address('10.0.4.4')

host_cores = 8
host_ram = 16
host_disk = 120
server_disk = 100

net_h1_name = 'net_h1'
net_h2_name = 'net_h2'
net_h3_name = 'net_h3'
net_h4_name = 'net_h4'

# All node properties
image = 'default_ubuntu_18'
# Out:
# Sites: TACC,TACC,TACC

# %% [markdown]
# ### Create the Slice

# %%
try:
    #Create Slice
    slice = fablib.new_slice(name=slice_name)
    
    # Add switch node s1
    s1 = slice.add_node(name=s1_name, site=site1,  image=image, 
                        cores=switch_cores, ram=switch_ram, disk=switch_disk)
    s1.set_capacities(cores=switch_cores, ram=switch_ram, disk=switch_disk)
    s1_iface_to_h1 = s1.add_component(model='NIC_Basic', name="s1_host1_nic").get_interfaces()[0]
    s1_iface_to_h2 = s1.add_component(model='NIC_Basic', name="s1_host2_nic").get_interfaces()[0]
    s1_iface_to_h3 = s1.add_component(model='NIC_Basic', name="s1_host3_nic").get_interfaces()[0]
    s1_iface_to_h4 = s1.add_component(model='NIC_Basic', name="s1_host4_nic").get_interfaces()[0]
    
    # Add host node h1
    h1 = slice.add_node(name=h1_name, site=site1, image=image,
                        cores=host_cores, ram=host_ram, disk=host_disk)
    h1_iface = h1.add_component(model='NIC_Basic', name="h1_nic").get_interfaces()[0]
    
    # Add host node h2
    h2 = slice.add_node(name=h2_name, site=site2, image=image,
                        cores=host_cores, ram=host_ram, disk=host_disk)
    h2_iface = h2.add_component(model='NIC_Basic', name="h2_nic").get_interfaces()[0]
    
    # Add host node h3
    h3 = slice.add_node(name=h3_name, site=site3, image=image,
                        cores=host_cores, ram=host_ram, disk=host_disk)
    h3_iface = h3.add_component(model='NIC_Basic', name="h3_nic").get_interfaces()[0]
    
    # Add host node h4
    h4 = slice.add_node(name=h4_name, site=site1, image=image,
                        cores=host_cores, ram=host_ram, disk=host_disk)
    h4_iface = h4.add_component(model='NIC_Basic', name="h4_nic").get_interfaces()[0]

    #Add switch-host links
    host_net1 = slice.add_l2network(name=net_h1_name, interfaces=[s1_iface_to_h1, h1_iface])
    host_net2 = slice.add_l2network(name=net_h2_name, interfaces=[s1_iface_to_h2, h2_iface])
    host_net3 = slice.add_l2network(name=net_h3_name, interfaces=[s1_iface_to_h3, h3_iface])
    host_net4 = slice.add_l2network(name=net_h4_name, interfaces=[s1_iface_to_h4, h4_iface])

    #Submit Slice Request
    slice.submit() 
except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()
# Out:
# Retry: 9, Time: 357 sec
# <style type="text/css">
# #T_bddea tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bddea tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bddea caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_bddea_row0_col0, #T_bddea_row0_col1, #T_bddea_row1_col0, #T_bddea_row1_col1, #T_bddea_row2_col0, #T_bddea_row2_col1, #T_bddea_row3_col0, #T_bddea_row3_col1, #T_bddea_row4_col0, #T_bddea_row4_col1, #T_bddea_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_bddea_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_bddea">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bddea_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_bddea_row0_col1" class="data row0 col1" >17222380-c6d2-44f0-836e-8b6b6f07f0b4</td>
#     </tr>
#     <tr>
#       <td id="T_bddea_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_bddea_row1_col1" class="data row1 col1" >DDOSM-18</td>
#     </tr>
#     <tr>
#       <td id="T_bddea_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T
row6_col4" class="data row6 col4" >None</td>
#       <td id="T_a3d76_row6_col5" class="data row6 col5" >12:2E:F1:97:38:02</td>
#       <td id="T_a3d76_row6_col6" class="data row6 col6" >ens7</td>
#       <td id="T_a3d76_row6_col7" class="data row6 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_a3d76_row7_col0" class="data row7 col0" >h4-h4_nic-p1</td>
#       <td id="T_a3d76_row7_col1" class="data row7 col1" >h4</td>
#       <td id="T_a3d76_row7_col2" class="data row7 col2" >net_h4</td>
#       <td id="T_a3d76_row7_col3" class="data row7 col3" >100</td>
#       <td id="T_a3d76_row7_col4" class="data row7 col4" >None</td>
#       <td id="T_a3d76_row7_col5" class="data row7 col5" >12:0E:02:F2:93:7E</td>
#       <td id="T_a3d76_row7_col6" class="data row7 col6" >ens7</td>
#       <td id="T_a3d76_row7_col7" class="data row7 col7" >ens7</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 399 seconds

# %% [markdown]
# ## Observe the Slice's Attributes
#
# ### Print the slice

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------  ------------------------------------
# Slice Name   DDOSM-P4
# Slice ID     4ea6203c-e32a-45df-8e78-d1b78828c363
# Slice State  StableOK
# Lease End    2023-05-02 07:55:18 +0000
# -----------  ------------------------------------

# %% [markdown]
# ### Print the Node List

# %%
try:
    slice = fablib.get_slice(name=slice_name)

    print(f"{slice.list_nodes()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_0a45a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0a45a th {
#   text-align: left;
# }
# #T_0a45a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a45a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0a45a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a45a_row0_col0, #T_0a45a_row0_col1, #T_0a45a_row0_col2, #T_0a45a_row0_col3, #T_0a45a_row0_col4, #T_0a45a_row0_col5, #T_0a45a_row0_col6, #T_0a45a_row0_col7, #T_0a45a_row0_col8, #T_0a45a_row0_col9, #T_0a45a_row0_col10, #T_0a45a_row0_col11, #T_0a45a_row0_col12, #T_0a45a_row0_col13, #T_0a45a_row0_col14, #T_0a45a_row0_col15, #T_0a45a_row1_col0, #T_0a45a_row1_col1, #T_0a45a_row1_col2, #T_0a45a_row1_col3, #T_0a45a_row1_col4, #T_0a45a_row1_col5, #T_0a45a_row1_col6, #T_0a45a_row1_col7, #T_0a45a_row1_col8, #T_0a45a_row1_col9, #T_0a45a_row1_col10, #T_0a45a_row1_col11, #T_0a45a_row1_col12, #T_0a45a_row1_col13, #T_0a45a_row1_col14, #T_0a45a_row1_col15, #T_0a45a_row2_col0, #T_0a45a_row2_col1, #T_0a45a_row2_col2, #T_0a45a_row2_col3, #T_0a45a_row2_col4, #T_0a45a_row2_col5, #T_0a45a_row2_col6, #T_0a45a_row2_col7, #T_0a45a_row2_col8, #T_0a45a_row2_col9, #T_0a45a_row2_col10, #T_0a45a_row2_col11, #T_0a45a_row2_col12, #T_0a45a_row2_col13, #T_0a45a_row2_col14, #T_0a45a_row2_col15, #T_0a45a_row3_col0, #T_0a45a_row3_col1, #T_0a45a_row3_col2, #T_0a45a_row3_col3, #T_0a45a_row3_col4, #T_0a45a_row3_col5, #T_0a45a_row3_col6, #T_0a45a_row3_col7, #T_0a45a_row3_col8, #T_0a45a_row3_col9, #T_0a45a_row3_col10, #T_0a45a_row3_col11, #T_0a45a_row3_col12, #T_0a45a_row3_col13, #T_0a45a_row3_col14, #T_0a45a_row3_col15, #T_0a45a_row4_col0, #T_0a45a_row4_col1, #T_0a45a_row4_col2, #T_0a45a_row4_col3, #T_0a45a_row4_col4, #T_0a45a_row4_col5, #T_0a45a_row4_col6, #T_0a45a_row4_col7, #T_0a45a_row4_col8, #T_0a45a_row4_col9, #T_0a45a_row4_col10, #T_0a45a_row4_col11, #T_0a45a_row4_col12, #T_0a45a_row4_col13, #T_0a45a_row4_col14, #T_0a45a_row4_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_0a45a">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_0a45a_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0a45a_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0a45a_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_0a45a_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_0a45a_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_0a45a_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_0a45a_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_0a45a_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_0a45a_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_0a45a_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_0a45a_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_0a45a_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_0a45a_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_0a45a_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_0a45a_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_0a45a_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a45a_row0_col0" class="data row0 col0" >e93277ed-9be6-4e93-a383-2c58c686c2bf</td>
#       <td id="T_0a45a_row0_col1" class="data row0 col1" >s1</td>
#       <td id="T_0a45a_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_0a45a_row0_col3" class="data row0 col3" >16</td>
#       <td id="T_0a45a_row0_col4" class="data row0 col4" >500</td>
#       <td id="T_0a45a_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_0a45a_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_0a45a_row0_col7" class="data row0 col7" >tacc-w2.fabric-testbed.net</td>
#       <td id="T_0a45a_row0_col8" class="data row0 col8" >TACC</td>
#       <td id="T_0a45a_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_0a45a_row0_col10" class="data row0 col10" >129.114.110.102</td>
#       <td id="T_0a45a_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_0a45a_row0_col12" class="data row0 col12" ></td>
#       <td id="T_0a45a_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.102</td>
#       <td id="T_0a45a_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0a45a_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0a45a_row1_col0" class="data row1 col0" >ce5a2088-fc57-4a5b-ad96-9872772cd531</td>
#       <td id="T_0a45a_row1_col1" class="data row1 col1" >h1</td>
#       <td id="T_0a45a_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_0a45a_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_0a45a_row1_col4" class="data row1 col4" >500</td>
#       <td id="T_0a45a_row1_col5" class="data row1 col5" >default_ubuntu_20</td>
#       <td id="T_0a45a_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_0a45a_row1_col7" class="data row1 col7" >tacc-w2.fabric-testbed.net</td>
#       <td id="T_0a45a_row1_col8" class="data row1 col8" >TACC</td>
#       <td id="T_0a45a_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_0a45a_row1_col10" class="data row1 col10" >129.114.110.80</td>
#       <td id="T_0a45a_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_0a45a_row1_col12" class="data row1 col12" ></td>
#       <td id="T_0a45a_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.80</td>
#       <td id="T_0a45a_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0a45a_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0a45a_row2_col0" class="data row2 col0" >618e3753-ccaa-453f-b24b-1435a354c07e</td>
#       <td id="T_0a45a_row2_col1" class="data row2 col1" >h2</td>
#       <td id="T_0a45a_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_0a45a_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_0a45a_row2_col4" class="data row2 col4" >500</td>
#       <td id="T_0a45a_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td id="T_0a45a_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_0a45a_row2_col7" class="data row2 col7" >tacc-w1.fabric-testbed.net</td>
#       <td id="T_0a45a_row2_col8" class="data row2 col8" >TACC</td>
#       <td id="T_0a45a_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_0a45a_row2_col10" class="data row2 col10" >129.114.110.84</td>
#       <td id="T_0a45a_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_0a45a_row2_col12" class="data row2 col12" ></td>
#       <td id="T_0a45a_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.84</td>
#       <td id="T_0a45a_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0a45a_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0a45a_row3_col0" class="data row3 col0" >f0db1523-bc1e-464a-b71e-138b4141093a</td>
#       <td id="T_0a45a_row3_col1" class="data row3 col1" >h3</td>
#       <td id="T_0a45a_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_0a45a_row3_col3" class="data row3 col3" >16</td>
#       <td id="T_0a45a_row3_col4" class="data row3 col4" >500</td>
#       <td id="T
# <pandas.io.formats.style.Styler object at 0x7fee74de9f70>

# %% [markdown]
# ### Print the Node Details

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    for node in slice.get_nodes():
        print(f"{node}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------------  ---------------------------------------------------------------------------------------------------------------------
# ID                 e93277ed-9be6-4e93-a383-2c58c686c2bf
# Name               s1
# Cores              8
# RAM                16
# Disk               500
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               tacc-w2.fabric-testbed.net
# Site               TACC
# Management IP      129.114.110.102
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.102
# -----------------  ---------------------------------------------------------------------------------------------------------------------
# -----------------  --------------------------------------------------------------------------------------------------------------------
# ID                 ce5a2088-fc57-4a5b-ad96-9872772cd531
# Name               h1
# Cores              8
# RAM                16
# Disk               500
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               tacc-w2.fabric-testbed.net
# Site               TACC
# Management IP      129.114.110.80
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.80
# -----------------  --------------------------------------------------------------------------------------------------------------------
# -----------------  --------------------------------------------------------------------------------------------------------------------
# ID                 618e3753-ccaa-453f-b24b-1435a354c07e
# Name               h2
# Cores              8
# RAM                16
# Disk               500
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               tacc-w1.fabric-testbed.net
# Site               TACC
# Management IP      129.114.110.84
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.84
# -----------------  --------------------------------------------------------------------------------------------------------------------
# -----------------  --------------------------------------------------------------------------------------------------------------------
# ID                 f0db1523-bc1e-464a-b71e-138b4141093a
# Name               h3
# Cores              8
# RAM                16
# Disk               500
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               tacc-w2.fabric-testbed.net
# Site               TACC
# Management IP      129.114.110.85
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.85
# -----------------  --------------------------------------------------------------------------------------------------------------------
# -----------------  ---------------------------------------------------------------------------------------------------------------------
# ID                 a1863b5d-c913-4452-b2b6-2a6f21c3d0a9
# Name               h4
# Cores              8
# RAM                16
# Disk               500
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               tacc-w2.fabric-testbed.net
# Site               TACC
# Management IP      129.114.110.110
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.110
# -----------------  ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Print the Node SSH Commands

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    for node in slice.get_nodes():
        print(f"{node.get_name()}: {node.get_ssh_command()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# s1: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.102
# h1: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.80
# h2: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.84
# h3: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.85
# h4: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@129.114.110.110

# %% [markdown]
# ### Print the Interfaces

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    
    print(f"{slice.list_interfaces()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_90784 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_90784 th {
#   text-align: left;
# }
# #T_90784 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_90784 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_90784 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_90784_row0_col0, #T_90784_row0_col1, #T_90784_row0_col2, #T_90784_row0_col3, #T_90784_row0_col4, #T_90784_row0_col5, #T_90784_row0_col6, #T_90784_row0_col7, #T_90784_row1_col0, #T_90784_row1_col1, #T_90784_row1_col2, #T_90784_row1_col3, #T_90784_row1_col4, #T_90784_row1_col5, #T_90784_row1_col6, #T_90784_row1_col7, #T_90784_row2_col0, #T_90784_row2_col1, #T_90784_row2_col2, #T_90784_row2_col3, #T_90784_row2_col4, #T_90784_row2_col5, #T_90784_row2_col6, #T_90784_row2_col7, #T_90784_row3_col0, #T_90784_row3_col1, #T_90784_row3_col2, #T_90784_row3_col3, #T_90784_row3_col4, #T_90784_row3_col5, #T_90784_row3_col6, #T_90784_row3_col7, #T_90784_row4_col0, #T_90784_row4_col1, #T_90784_row4_col2, #T_90784_row4_col3, #T_90784_row4_col4, #T_90784_row4_col5, #T_90784_row4_col6, #T_90784_row4_col7, #T_90784_row5_col0, #T_90784_row5_col1, #T_90784_row5_col2, #T_90784_row5_col3, #T_90784_row5_col4, #T_90784_row5_col5, #T_90784_row5_col6, #T_90784_row5_col7, #T_90784_row6_col0, #T_90784_row6_col1, #T_90784_row6_col2, #T_90784_row6_col3, #T_90784_row6_col4, #T_90784_row6_col5, #T_90784_row6_col6, #T_90784_row6_col7, #T_90784_row7_col0, #T_90784_row7_col1, #T_90784_row7_col2, #T_90784_row7_col3, #T_90784_row7_col4, #T_90784_row7_col5, #T_90784_row7_col6, #T_90784_row7_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_90784">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_90784_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_90784_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_90784_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_90784_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_90784_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_90784_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_90784_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_90784_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_90784_row0_col0" class="data row0 col0" >s1-s1_host1_nic-p1</td>
#       <td id="T_90784_row0_col1" class="data row0 col1" >s1</td>
#       <td id="T_90784_row0_col2" class="data row0 col2" >net_h1</td>
#       <td id="T_90784_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_90784_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_90784_row0_col5" class="data row0 col5" >0A:03:0A:F5:B1:53</td>
#       <td id="T_90784_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_90784_row0_col7" class="data row0 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_90784_row1_col0" class="data row1 col0" >s1-s1_host4_nic-p1</td>
#       <td id="T_90784_row1_col1" class="data row1 col1" >s1</td>
#       <td id="T_90784_row1_col2" class="data row1 col2" >net_h4</td>
#       <td id="T_90784_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_90784_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_90784_row1_col5" class="data row1 col5" >06:A8:0F:D7:32:FB</td>
#       <td id="T_90784_row1_col6" class="data row1 col6" >ens9</td>
#       <td id="T_90784_row1_col7" class="data row1 col7" >ens9</td>
#     </tr>
#     <tr>
#       <td id="T_90784_row2_col0" class="data row2 col0" >s1-s1_host2_nic-p1</td>
#       <td id="T_90784_row2_col1" class="data row2 col1" >s1</td>
#       <td id="T_90784_row2_col2" class="data row2 col2" >net_h2</td>
#       <td id="T_90784_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_90784_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_90784_row2_col5" class="data row2 col5" >02:7F:22:D0:3A:53</td>
#       <td id="T_90784_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_90784_row2_col7" class="data row2 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_90784_row3_col0" class="data row3 col0" >s1-s1_host3_nic-p1</td>
#       <td id="T_90784_row3_col1" class="data row3 col1" >s1</td>
#       <td id="T_90784_row3_col2" class="data row3 col2" >net_h3</td>
#       <td id="T_90784_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_90784_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_90784_row3_col5" class="data row3 col5" >02:EE:00:C6:75:96</td>
#       <td id="T_90784_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_90784_row3_col7" class="data row3 col7" >None</td>
#     </tr>
#     <tr>
#       <td id="T_90784_row4_col0" class="data row4 col0" >h1-h1_nic-p1</td>
#       <td id="T_90784_row4_col1" class="data row4 col1" >h1</td>
#       <td id="T_90784_row4_col2" class="data row4 col2" >net_h1</td>
#       <td id="T_90784_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_90784_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_90784_row4_col5" class="data row4 col5" >0A:7C:D4:F9:5A:E4</td>
#       <td id="T_90784_row4_col6" class="data row4 col6" >ens7</td>
#       <td id="T_90784_row4_col7" class="data row4 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_90784_row5_col0" class="data row5 col0" >h2-h2_nic-p1</td>
#       <td id="T_90784_row5_col1" class="data row5 col1" >h2</td>
#       <td id="T_90784_row5_col2" class="data row5 col2" >net_h2</td>
#       <td id="T_90784_row5_col3" class="data row5 col3" >100</td>
#       <td id="T_90784_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_90784_row5_col5" class="data row5 col5" >02:26:69:8A:CD:1F</td>
#       <td id="T_90784_row5_col6" class="data row5 col6" >ens7</td>
#       <td id="T_90784_row5_col7" class="data row5 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_90784_row6_col0" class="data row6 col0" >h3-h3_nic-p1</td>
#       <td id="T_90784_row6_col1" class="data row6 col1" >h3</td>
#       <td id="T_90784_row6_col2" class="data row6 col2" >net_h3</td>
#       <td id="T_90784_row6_col3" class="data row6 col3" >100</td>
#       <td id="T_90784_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_90784_row6_col5" class="data row6 col5" >0A:A6:17:C6:65:D0</td>
#       <td id="T_90784_row6_col6" class="data row6 col6" >ens7</td>
#       <td id="T_90784_row6_col7" class="data row6 col7" >ens7</td>
#     </tr>
#     <tr>
#       <td id="T_90784_row7_col0" class="data row7 col0" >h4-h4_nic-p1</td>
#       <td id="T_90784_row7_col1" class="data row7 col1" >h4</td>
#       <td id="T_90784_row7_col2" class="data row7 col2" >net_h4</td>
#       <td id="T_90784_row7_col3" class="data row7 col3" >100</td>
#       <td id="T_90784_row7_col4" class="data row7 col4" >None</td>
#       <td id="T_90784_row7_col5" class="data row7 col5" >02:2A:1F:68:A6:C7</td>
#       <td id="T_90784_row7_col6" class="data row7 col6" >ens7</td>
#       <td id="T_90784_row7_col7" class="data row7 col7" >ens7</td>
#     </tr>
#   </tbody>
# </table>
# <pandas.io.formats.style.Styler object at 0x7fee9c196e80>

# %% [markdown]
# ## Configure Nodes

# %%
config_threads = {}

# %%
host_config_script = "sudo apt-get update -qq && sudo apt-get install -qq -y python3-scapy && git clone https://github.com/p4lang/tutorials.git/" 

try:
    
    
    h1 = slice.get_node(name=h1_name)        
    if type(ip_address(h1.get_management_ip())) is IPv6Address:
        h1.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")
       
    h1_os_iface = h1.get_interface(network_name=net_h1_name)
    h1_os_iface.ip_addr_add(addr=h1_addr, subnet=h1_subnet)
    h1_config_thread = h1.execute_thread(host_config_script)
    config_threads[h1] = h1_config_thread

    
    h2 = slice.get_node(name=h2_name)
    if type(ip_address(h2.get_management_ip())) is IPv6Address:
        h2.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")
 
    h2_os_iface = h2.get_interface(network_name=net_h2_name)
    h2_os_iface.ip_addr_add(addr=h2_addr, subnet=h2_subnet)
    h2_config_thread = h2.execute_thread(host_config_script)
    config_threads[h2] = h2_config_thread

    h3 = slice.get_node(name=h3_name)
    if type(ip_address(h3.get_management_ip())) is IPv6Address:
        h3.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")
 
    h3_os_iface = h3.get_interface(network_name=net_h3_name)
    h3_os_iface.ip_addr_add(addr=h3_addr, subnet=h3_subnet)
    h3_config_thread = h3.execute_thread(host_config_script)
    config_threads[h3] = h3_config_thread
    
    h4 = slice.get_node(name=h4_name)
    if type(ip_address(h4.get_management_ip())) is IPv6Address:
        h4.execute("sudo sed -i '/nameserver/d' /etc/resolv.conf && sudo sh -c 'echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf' && sudo sh -c 'echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf'")

    h4_os_iface = h4.get_interface(network_name=net_h4_name)
    h4_os_iface.ip_addr_add(addr=h4_addr, subnet=h4_subnet)
    h4_config_thread = h4.execute_thread(host_config_script)
    config_threads[h4] = h4_config_thread


except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()

# %% [markdown]
# ## Configure Switches
#
# Use ssh to configure the ifaces on the switches. This step requires testing the interfaces to figure out which interface is connected to which network.

# %% [markdown]
# #### Setup P4 Docker

# %% [markdown]
# Below are commands to let sudo work with the global proxy.

# %%
s1 = slice.get_node(name=s1_name)
s1.upload_file('CSE545-AWS.pem','CSE545-AWS.pem')
# Out:
# <SFTPAttributes: [ size=0 uid=1000 gid=1000 mode=0o100664 atime=1682993793 mtime=1682993793 ]>

# %%
try:
    s1 = slice.get_node(name=s1_name)
    s1_h1_os_iface = s1.get_interface(network_name=net_h1_name)
    s1_h2_os_iface = s1.get_interface(network_name=net_h2_name)
    s1_h3_os_iface = s1.get_interface(network_name=net_h3_name)
    s1_h4_os_iface = s1.get_interface(network_name=net_h4_name)
        
    if type(ip_address(s1.get_management_ip())) is IPv4Address:
        management_ip_type = "IPv4"
    else:
        management_ip_type = "IPv6"
    
    file_attributes = s1.upload_file('./scripts/router_setup_p4_bmv2_container.sh','router_setup_p4_bmv2_container.sh')
    command=f"chmod +x router_setup_p4_bmv2_container.sh && sudo sh -c './router_setup_p4_bmv2_container.sh  {management_ip_type} {s1_h1_os_iface.get_os_interface()} {s1_h2_os_iface.get_os_interface()} {s1_h3_os_iface.get_os_interface()} {s1_h4_os_iface.get_os_interface()} > /tmp/script.log 2>&1'"
    s1_config_thread = s1.execute_thread(command)
    config_threads[s1] = s1_config_thread


except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()

# %%
try:
    for node, thread in config_threads.items():
        stdout, stderr = thread.result()
        print(f"Config thread node {node.get_name()} complete")
        print(f"stdout: {stdout}")
        print(f"stderr: {stderr}")
except Exception as e:
    print(f"Error: {e}")
    traceback.print_exc()
# Out:
# Config thread node h1 complete
# stdout: Selecting previously unselected package python3-backcall.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../00-python3-backcall_0.1.0-2_all.deb ...
# Unpacking python3-backcall (0.1.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../01-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../02-python3-parso_0.5.2-1ubuntu1_all.deb ...
# Unpacking python3-parso (0.5.2-1ubuntu1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../03-python3-jedi_0.15.2-1_all.deb ...
# Unpacking python3-jedi (0.15.2-1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../04-python3-pickleshare_0.7.5-2_all.deb ...
# Unpacking python3-pickleshare (0.7.5-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../05-python3-wcwidth_0.1.8+dfsg1-3_all.deb ...
# Unpacking python3-wcwidth (0.1.8+dfsg1-3) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../06-python3-prompt-toolkit_2.0.10-2_all.deb ...
# Unpacking python3-prompt-toolkit (2.0.10-2) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../07-python3-pygments_2.3.1+dfsg-1ubuntu2.2_all.deb ...
# Unpacking python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../08-python3-ipython-genutils_0.2.0-1ubuntu1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../09-python3-traitlets_4.3.3-3_all.deb ...
# Unpacking python3-traitlets (4.3.3-3) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../10-python3-ipython_7.13.0-1_all.deb ...
# Unpacking python3-ipython (7.13.0-1) ...
# Selecting previously unselected package ipython3.
# Preparing to unpack .../11-ipython3_7.13.0-1_all.deb ...
# Unpacking ipython3 (7.13.0-1) ...
# Selecting previously unselected package python3-scapy.
# Preparing to unpack .../12-python3-scapy_2.4.3-4_all.deb ...
# Unpacking python3-scapy (2.4.3-4) ...
# Setting up python3-backcall (0.1.0-2) ...
# Setting up python3-parso (0.5.2-1ubuntu1) ...
# Setting up python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Setting up python3-wcwidth (0.1.8+dfsg1-3) ...
# Setting up python3-pickleshare (0.7.5-2) ...
# Setting up python3-scapy (2.4.3-4) ...
# Setting up python3-traitlets (4.3.3-3) ...
# Setting up python3-prompt-toolkit (2.0.10-2) ...
# Setting up python3-jedi (0.15.2-1) ...
# Setting up python3-ipython (7.13.0-1) ...
# Setting up ipython3 (7.13.0-1) ...
# Processing triggers for man-db (2.9.1-1) ...
#
# stderr: debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Cloning into 'tutorials'...
#
# Config thread node h2 complete
# stdout: Selecting previously unselected package python3-backcall.
# (Reading database ... 94728 files and directories currently installed.)
# Preparing to unpack .../00-python3-backcall_0.1.0-2_all.deb ...
# Unpacking python3-backcall (0.1.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../01-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../02-python3-parso_0.5.2-1ubuntu1_all.deb ...
# Unpacking python3-parso (0.5.2-1ubuntu1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../03-python3-jedi_0.15.2-1_all.deb ...
# Unpacking python3-jedi (0.15.2-1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../04-python3-pickleshare_0.7.5-2_all.deb ...
# Unpacking python3-pickleshare (0.7.5-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../05-python3-wcwidth_0.1.8+dfsg1-3_all.deb ...
# Unpacking python3-wcwidth (0.1.8+dfsg1-3) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../06-python3-prompt-toolkit_2.0.10-2_all.deb ...
# Unpacking python3-prompt-toolkit (2.0.10-2) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../07-python3-pygments_2.3.1+dfsg-1ubuntu2.2_all.deb ...
# Unpacking python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../08-python3-ipython-genutils_0.2.0-1ubuntu1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../09-python3-traitlets_4.3.3-3_all.deb ...
# Unpacking python3-traitlets (4.3.3-3) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../10-python3-ipython_7.13.0-1_all.deb ...
# Unpacking python3-ipython (7.13.0-1) ...
# Selecting previously unselected package ipython3.
# Preparing to unpack .../11-ipython3_7.13.0-1_all.deb ...
# Unpacking ipython3 (7.13.0-1) ...
# Selecting previously unselected package python3-scapy.
# Preparing to unpack .../12-python3-scapy_2.4.3-4_all.deb ...
# Unpacking python3-scapy (2.4.3-4) ...
# Setting up python3-backcall (0.1.0-2) ...
# Setting up python3-parso (0.5.2-1ubuntu1) ...
# Setting up python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Setting up python3-wcwidth (0.1.8+dfsg1-3) ...
# Setting up python3-pickleshare (0.7.5-2) ...
# Setting up python3-scapy (2.4.3-4) ...
# Setting up python3-traitlets (4.3.3-3) ...
# Setting up python3-prompt-toolkit (2.0.10-2) ...
# Setting up python3-jedi (0.15.2-1) ...
# Setting up python3-ipython (7.13.0-1) ...
# Setting up ipython3 (7.13.0-1) ...
# Processing triggers for man-db (2.9.1-1) ...
#
# stderr: debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Cloning into 'tutorials'...
#
# Config thread node h3 complete
# stdout: Selecting previously unselected package python3-backcall.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../00-python3-backcall_0.1.0-2_all.deb ...
# Unpacking python3-backcall (0.1.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../01-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../02-python3-parso_0.5.2-1ubuntu1_all.deb ...
# Unpacking python3-parso (0.5.2-1ubuntu1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../03-python3-jedi_0.15.2-1_all.deb ...
# Unpacking python3-jedi (0.15.2-1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../04-python3-pickleshare_0.7.5-2_all.deb ...
# Unpacking python3-pickleshare (0.7.5-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../05-python3-wcwidth_0.1.8+dfsg1-3_all.deb ...
# Unpacking python3-wcwidth (0.1.8+dfsg1-3) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../06-python3-prompt-toolkit_2.0.10-2_all.deb ...
# Unpacking python3-prompt-toolkit (2.0.10-2) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../07-python3-pygments_2.3.1+dfsg-1ubuntu2.2_all.deb ...
# Unpacking python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../08-python3-ipython-genutils_0.2.0-1ubuntu1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../09-python3-traitlets_4.3.3-3_all.deb ...
# Unpacking python3-traitlets (4.3.3-3) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../10-python3-ipython_7.13.0-1_all.deb ...
# Unpacking python3-ipython (7.13.0-1) ...
# Selecting previously unselected package ipython3.
# Preparing to unpack .../11-ipython3_7.13.0-1_all.deb ...
# Unpacking ipython3 (7.13.0-1) ...
# Selecting previously unselected package python3-scapy.
# Preparing to unpack .../12-python3-scapy_2.4.3-4_all.deb ...
# Unpacking python3-scapy (2.4.3-4) ...
# Setting up python3-backcall (0.1.0-2) ...
# Setting up python3-parso (0.5.2-1ubuntu1) ...
# Setting up python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Setting up python3-wcwidth (0.1.8+dfsg1-3) ...
# Setting up python3-pickleshare (0.7.5-2) ...
# Setting up python3-scapy (2.4.3-4) ...
# Setting up python3-traitlets (4.3.3-3) ...
# Setting up python3-prompt-toolkit (2.0.10-2) ...
# Setting up python3-jedi (0.15.2-1) ...
# Setting up python3-ipython (7.13.0-1) ...
# Setting up ipython3 (7.13.0-1) ...
# Processing triggers for man-db (2.9.1-1) ...
#
# stderr: debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Cloning into 'tutorials'...
#
# Config thread node h4 complete
# stdout: Selecting previously unselected package python3-backcall.
# (Reading database ... 63577 files and directories currently installed.)
# Preparing to unpack .../00-python3-backcall_0.1.0-2_all.deb ...
# Unpacking python3-backcall (0.1.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../01-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../02-python3-parso_0.5.2-1ubuntu1_all.deb ...
# Unpacking python3-parso (0.5.2-1ubuntu1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../03-python3-jedi_0.15.2-1_all.deb ...
# Unpacking python3-jedi (0.15.2-1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../04-python3-pickleshare_0.7.5-2_all.deb ...
# Unpacking python3-pickleshare (0.7.5-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../05-python3-wcwidth_0.1.8+dfsg1-3_all.deb ...
# Unpacking python3-wcwidth (0.1.8+dfsg1-3) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../06-python3-prompt-toolkit_2.0.10-2_all.deb ...
# Unpacking python3-prompt-toolkit (2.0.10-2) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../07-python3-pygments_2.3.1+dfsg-1ubuntu2.2_all.deb ...
# Unpacking python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../08-python3-ipython-genutils_0.2.0-1ubuntu1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../09-python3-traitlets_4.3.3-3_all.deb ...
# Unpacking python3-traitlets (4.3.3-3) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../10-python3-ipython_7.13.0-1_all.deb ...
# Unpacking python3-ipython (7.13.0-1) ...
# Selecting previously unselected package ipython3.
# Preparing to unpack .../11-ipython3_7.13.0-1_all.deb ...
# Unpacking ipython3 (7.13.0-1) ...
# Selecting previously unselected package python3-scapy.
# Preparing to unpack .../12-python3-scapy_2.4.3-4_all.deb ...
# Unpacking python3-scapy (2.4.3-4) ...
# Setting up python3-backcall (0.1.0-2) ...
# Setting up python3-parso (0.5.2-1ubuntu1) ...
# Setting up python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Setting up python3-wcwidth (0.1.8+dfsg1-3) ...
# Setting up python3-pickleshare (0.7.5-2) ...
# Setting up python3-scapy (2.4.3-4) ...
# Setting up python3-traitlets (4.3.3-3) ...
# Setting up python3-prompt-toolkit (2.0.10-2) ...
# Setting up python3-jedi (0.15.2-1) ...
# Setting up python3-ipython (7.13.0-1) ...
# Setting up ipython3 (7.13.0-1) ...
# Processing triggers for man-db (2.9.1-1) ...
#
# stderr: debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Cloning into 'tutorials'...
#
# Config thread node s1 complete
# stdout:
# stderr:

# %% [markdown]
# ### Confgure P4 Switch Tables
#
# Edit sX_commands.txt to change the values

# %%
switch_name = s1_name
switch_node = slice.get_node(name=switch_name)
management_ip_switch = str(switch_node.get_management_ip())
print("Swtitch Name        : {}".format(switch_node.get_name()))
print("Management IP    : {}".format(management_ip_switch))

#Configure P4 Tables
cmd_file=f'{switch_name}_commands.txt'
print(cmd_file)
file_attributes = switch_node.upload_file(f'scripts/{cmd_file}',cmd_file)
print("file_attributes: {}".format(file_attributes))

stdout = switch_node.execute(f"sudo sh -c 'cat {cmd_file} | docker exec -i fabric_p4 simple_switch_CLI'")
print("stdout: {}".format(stdout))
# Out:
# Swtitch Name        : s1
# Management IP    : 129.114.110.102
# s1_commands.txt
# file_attributes: -rw-rw-r--   1 1000     1000          234 01 May 07:10 ?
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Setting default action of myTunnel_exact
# action:              drop
# runtime data:
# RuntimeCmd: Adding entry to exact match table myTunnel_exact
# match key:           EXACT-00:01
# action:              myTunnel_forward
# runtime data:        00:01
# Invalid table operation (DUPLICATE_ENTRY)
# RuntimeCmd: Adding entry to exact match table myTunnel_exact
# match key:           EXACT-00:02
# action:              myTunnel_forward
# runtime data:        00:02
# Invalid table operation (DUPLICATE_ENTRY)
# RuntimeCmd: Adding entry to exact match table myTunnel_exact
# match key:           EXACT-00:03
# action:              myTunnel_forward
# runtime data:        00:03
# Invalid table operation (DUPLICATE_ENTRY)
# RuntimeCmd: Adding entry to exact match table myTunnel_exact
# match key:           EXACT-00:04
# action:              myTunnel_forward
# runtime data:        00:04
# Entry has been added with handle 3
# RuntimeCmd:
# stdout: ('Obtaining JSON from switch...\nDone\nControl utility for runtime P4 table manipulation\nRuntimeCmd: Setting default action of myTunnel_exact\naction:              drop\nruntime data:        \nRuntimeCmd: Adding entry to exact match table myTunnel_exact\nmatch key:           EXACT-00:01\naction:              myTunnel_forward\nruntime data:        00:01\nInvalid table operation (DUPLICATE_ENTRY)\nRuntimeCmd: Adding entry to exact match table myTunnel_exact\nmatch key:           EXACT-00:02\naction:              myTunnel_forward\nruntime data:        00:02\nInvalid table operation (DUPLICATE_ENTRY)\nRuntimeCmd: Adding entry to exact match table myTunnel_exact\nmatch key:           EXACT-00:03\naction:              myTunnel_forward\nruntime data:        00:03\nInvalid table operation (DUPLICATE_ENTRY)\nRuntimeCmd: Adding entry to exact match table myTunnel_exact\nmatch key:           EXACT-00:04\naction:              myTunnel_forward\nruntime data:        00:04\nEntry has been added with handle 3\nRuntimeCmd: \n', '')

# %% [markdown]
# ## The switches are now configured and running. Now we are going to send packets over the switches.

# %% [markdown]
# We are going to use `send.py` and `receive.py`. We are going to re-upload them to the servers and use them. Make sure to modify the interface names in the script accordingly.

# %%
h1.upload_file('scripts/send.py', 'tutorials/exercises/basic_tunnel/send_modified.py')
h4.upload_file('scripts/receive.py', 'tutorials/exercises/basic_tunnel/receive_modified.py')

#h1.execute('sudo mv send.py tutorials/exercises/basic_tunnel/send_modified.py')
#h2.execute('sudo mv receive.py tutorials/exercises/basic_tunnel/receive_modified.py')
# Out:
# <SFTPAttributes: [ size=882 uid=1000 gid=1000 mode=0o100664 atime=1682925152 mtime=1682925152 ]>

# %% [markdown]
# ## Below, we send a few packets.

# %%
h1.execute('tmux new -d \'timeout 30 watch -n 5 sudo python3 tutorials/exercises/basic_tunnel/send_modified.py --dst_id 2 10.10.4.4 "message100"\'')
# Out:
# ('', '')

# %% [markdown]
# ## And below we receive them.

# %%
print(h4.execute('sudo timeout 30 sudo python3 tutorials/exercises/basic_tunnel/receive_modified.py')[0])
# Out:
# ['ens7', 'ens3']
# sniffing on ens3
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# ['ens7', 'ens3']
# sniffing on ens3
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'
#
# got a packet
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = fa:16:3e:52:f8:0c
#   type      = 0x1212
# ###[ MyTunnel ]###
#      pid       = 2048
#      dst_id    = 2
# ###[ IP ]###
#         version   = 4
#         ihl       = 5
#         tos       = 0x0
#         len       = 30
#         id        = 1
#         flags     =
#         frag      = 0
#         ttl       = 64
#         proto     = hopopt
#         chksum    = 0x5cd8
#         src       = 10.20.5.230
#         dst       = 10.10.4.4
#         \options   \
# ###[ Raw ]###
#            load      = 'message100'

# %% [markdown]
#  ## Delete Slice

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Fail: {e}")
    traceback.print_exc()

# %% [markdown]
# ## Get and Renew the Slice
#
# You slice is in the list of all your slices. You can loop through the list of slices to get the slice. Python has a standard tool to filter lists. Try using a lambda function to filter out your slice using its name.
#
# The new end date is in UTC.

# %%
from datetime import datetime
from datetime import timezone
from datetime import timedelta

#Set end host to now plus 1 day
end_date = (datetime.now(timezone.utc) + timedelta(days=1)).strftime("%Y-%m-%d %H:%M:%S %z")

try:
    slice = fablib.get_slice(name=slice_name)

    slice.renew(end_date)
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Check New Lease End Date

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"Lease End (UTC)        : {slice.get_lease_end()}")
       
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Lease End (UTC)        : 2023-05-02 07:55:18 +0000
